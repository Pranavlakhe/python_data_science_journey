# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranavlakhe/python_data_science_journey/blob/main/01_Python/01_variables_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# Out:
# git version 2.43.0

# %%
# !git config --global user.name "Pranav Lakhe"

# %%
# !git config --global user.email "Pranavlakhe742gmail.com"

# %%
# !rm -rf python-data-science-journey
